# %%
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# # 1 : Climate

# %%
climate = pd.read_csv("data/climate_change_data.csv", parse_dates = True)
climate.shape
# Out:
# (10000, 9)

# %%
# Relevant Years - most recent climate metircs
climate = climate[climate['Date'] >= '2020']
climate.shape
# Out:
# (1304, 9)

# %%
# check for missing data
climate.isnull().sum()
# Out:
# Date              0
# Location          0
# Country           0
# Temperature       0
# CO2 Emissions     0
# Sea Level Rise    0
# Precipitation     0
# Humidity          0
# Wind Speed        0
# dtype: int64

# %%
# columns present in dataset
climate.columns
# Out:
# Index(['Date', 'Location', 'Country', 'Temperature', 'CO2 Emissions',
#        'Sea Level Rise', 'Precipitation', 'Humidity', 'Wind Speed'],
#       dtype='object')

# %%
# columns data types
climate.dtypes
# Out:
# Date               object
# Location           object
# Country            object
# Temperature       float64
# CO2 Emissions     float64
# Sea Level Rise    float64
# Precipitation     float64
# Humidity          float64
# Wind Speed        float64
# dtype: object

# %%
n = climate['Location'].nunique()
print(f"There are climate metrics taken for {n} different locations.")
# Out:
# There are climate metrics taken for 1241 different locations.

# %% [markdown]
# # 2 : Disasters

# %%
disasters = pd.read_csv("data/natural-disasters copy.csv")
disasters.shape
# Out:
# (7081, 169)

# %%
disasters = disasters[disasters['Year'] >= 2020]
disasters
# Out:
#      Country name  Year  Number of deaths from drought  \
# 44    Afghanistan  2020                            NaN
# 45    Afghanistan  2021                            0.0
# 46    Afghanistan  2022                            NaN
# 47    Afghanistan  2023                            NaN
# 127        Africa  2020                            0.0
# ...           ...   ...                            ...
# 7060       Zambia  2022                            NaN
# 7061       Zambia  2023                            NaN
# 7078     Zimbabwe  2021                            0.0
# 7079     Zimbabwe  2022                            NaN
# 7080     Zimbabwe  2023                            NaN
#
#       Number of people injured from drought  \
# 44                                      NaN
# 45                                      0.0
# 46                                      NaN
# 47                                      NaN
# 127                                     0.0
# ...                                     ...
# 7060                                    NaN
# 7061                                    NaN
# 7078                                    0.0
# 7079                                    NaN
# 7080                                    NaN
#
#       Number of people affected from drought  \
# 44                                       NaN
# 45                                11000000.0
# 46                                       NaN
# 47                                       NaN
# 127                               33189316.0
# ...                                      ...
# 7060                                     NaN
# 7061                                     NaN
# 7078                                167500.0
# 7079                                     NaN
# 7080                                     NaN
#
#       Number of people left homeless from drought  \
# 44                                            NaN
# 45                                            0.0
# 46                                            NaN
# 47                                            NaN
# 127                                           0.0
# ...                                           ...
# 7060                                          NaN
# 7061                                          NaN
# 7078                                          0.0
# 7079                                          NaN
# 7080                                          NaN
#
#       Number of total people affected by drought  \
# 44                                           NaN
# 45                                    11000000.0
# 46                                           NaN
# 47                                           NaN
# 127                                   33189316.0
# ...                                          ...
# 7060                                         NaN
# 7061                                         NaN
# 7078                                    167500.0
# 7079                                         NaN
# 7080                                         NaN
#
#       Reconstruction costs from drought  Insured damages against drought  \
# 44                                  NaN                              NaN
# 45                                  0.0                              0.0
# 46                                  NaN                              NaN
# 47                                  NaN                              NaN
# 127                                 0.0                              0.0
# ...                                 ...                              ...
# 7060                                NaN                              NaN
# 7061                                NaN                              NaN
# 7078                                0.0                              0.0
# 7079                                NaN                              NaN
# 7080                                NaN                              NaN
#
#       Total economic damages from drought  ...  \
# 44                                    NaN  ...
# 45                           0.000000e+00  ...
# 46                                    NaN  ...
# 47                                    NaN  ...
# 127                          1.243000e+09  ...
# ...                                   ...  ...
# 7060                                  NaN  ...
# 7061                                  NaN  ...
# 7078                         0.000000e+00  ...
# 7079                                  NaN  ...
# 7080                                  NaN  ...
#
#       Total economic damages from drought as a share of GDP  \
# 44                                                  NaN
# 45                                                  0.0
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                0.0
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from earthquakes as a share of GDP  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from extreme temperatures as a share of GDP  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from floods as a share of GDP  \
# 44                                                  0.0
# 45                                                  0.0
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from landslides as a share of GDP  \
# 44                                                  0.0
# 45                                                  0.0
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from mass movements as a share of GDP  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from storms as a share of GDP  \
# 44                                                  0.0
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                0.0
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from volcanic activity as a share of GDP  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from volcanic activity as a share of GDP.1  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       total_damages_pct_gdp_glacial_lake
# 44                                   NaN
# 45                                   NaN
# 46                                   NaN
# 47                                   NaN
# 127                                  NaN
# ...                                  ...
# 7060                                 NaN
# 7061                                 NaN
# 7078                                 NaN
# 7079                                 NaN
# 7080                                 NaN
#
# [528 rows x 169 columns]

# %%
disasters.shape
# Out:
# (528, 169)

# %%
disasters.columns
# Out:
# Index(['Country name', 'Year', 'Number of deaths from drought',
#        'Number of people injured from drought',
#        'Number of people affected from drought',
#        'Number of people left homeless from drought',
#        'Number of total people affected by drought',
#        'Reconstruction costs from drought', 'Insured damages against drought',
#        'Total economic damages from drought',
#        ...
#        'Total economic damages from drought as a share of GDP',
#        'Total economic damages from earthquakes as a share of GDP',
#        'Total economic damages from extreme temperatures as a share of GDP',
#        'Total economic damages from floods as a share of GDP',
#        'Total economic damages from landslides as a share of GDP',
#        'Total economic damages from mass movements as a share of GDP',
#        'Total economic damages from storms as a share of GDP',
#        'Total economic damages from volcanic activity as a share of GDP',
#        'Total economic damages from volcanic activity as a share of GDP.1',
#        'total_damages_pct_gdp_glacial_lake'],
#       dtype='object', length=169)

# %%
# removing columns containing the words "Number of"
columns_to_drop = [col for col in disasters.columns if 'Number of' in col]

# dropping the columns
disasters.drop(columns = columns_to_drop, inplace = True)
disasters.shape
# Out:
# (528, 97)

# %%
# removing columns containing "Total number of peopl"
columns_to_drop = [col for col in disasters.columns if 'Total number of people affected by' in col and 'per 100,000' in col]

# Drop the filtered columns
disasters.drop(columns=columns_to_drop, inplace=True)
disasters.shape
# Out:
# (528, 85)

# %%
disasters
# Out:
#      Country name  Year  Reconstruction costs from drought  \
# 44    Afghanistan  2020                                NaN
# 45    Afghanistan  2021                                0.0
# 46    Afghanistan  2022                                NaN
# 47    Afghanistan  2023                                NaN
# 127        Africa  2020                                0.0
# ...           ...   ...                                ...
# 7060       Zambia  2022                                NaN
# 7061       Zambia  2023                                NaN
# 7078     Zimbabwe  2021                                0.0
# 7079     Zimbabwe  2022                                NaN
# 7080     Zimbabwe  2023                                NaN
#
#       Insured damages against drought  Total economic damages from drought  \
# 44                                NaN                                  NaN
# 45                                0.0                         0.000000e+00
# 46                                NaN                                  NaN
# 47                                NaN                                  NaN
# 127                               0.0                         1.243000e+09
# ...                               ...                                  ...
# 7060                              NaN                                  NaN
# 7061                              NaN                                  NaN
# 7078                              0.0                         0.000000e+00
# 7079                              NaN                                  NaN
# 7080                              NaN                                  NaN
#
#       Death rates from drought  Injury rates from drought  \
# 44                         NaN                        NaN
# 45                         0.0                        0.0
# 46                         NaN                        NaN
# 47                         NaN                        NaN
# 127                        0.0                        0.0
# ...                        ...                        ...
# 7060                       NaN                        NaN
# 7061                       NaN                        NaN
# 7078                       0.0                        0.0
# 7079                       NaN                        NaN
# 7080                       NaN                        NaN
#
#       Homelessness rate from drought  Reconstruction costs from earthquakes  \
# 44                               NaN                                    NaN
# 45                               0.0                                    NaN
# 46                               NaN                                    0.0
# 47                               NaN                                    0.0
# 127                              0.0                                    0.0
# ...                              ...                                    ...
# 7060                             NaN                                    NaN
# 7061                             NaN                                    NaN
# 7078                             0.0                                    NaN
# 7079                             NaN                                    NaN
# 7080                             NaN                                    NaN
#
#       Insured damages against earthquakes  ...  \
# 44                                    NaN  ...
# 45                                    NaN  ...
# 46                                    0.0  ...
# 47                                    0.0  ...
# 127                                   0.0  ...
# ...                                   ...  ...
# 7060                                  NaN  ...
# 7061                                  NaN  ...
# 7078                                  NaN  ...
# 7079                                  NaN  ...
# 7080                                  NaN  ...
#
#       Total economic damages from drought as a share of GDP  \
# 44                                                  NaN
# 45                                                  0.0
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                0.0
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from earthquakes as a share of GDP  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from extreme temperatures as a share of GDP  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from floods as a share of GDP  \
# 44                                                  0.0
# 45                                                  0.0
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from landslides as a share of GDP  \
# 44                                                  0.0
# 45                                                  0.0
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from mass movements as a share of GDP  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from storms as a share of GDP  \
# 44                                                  0.0
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                0.0
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from volcanic activity as a share of GDP  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       Total economic damages from volcanic activity as a share of GDP.1  \
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 127                                                 NaN
# ...                                                 ...
# 7060                                                NaN
# 7061                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
#
#       total_damages_pct_gdp_glacial_lake
# 44                                   NaN
# 45                                   NaN
# 46                                   NaN
# 47                                   NaN
# 127                                  NaN
# ...                                  ...
# 7060                                 NaN
# 7061                                 NaN
# 7078                                 NaN
# 7079                                 NaN
# 7080                                 NaN
#
# [528 rows x 85 columns]

# %%
disasters.isnull().sum() > 0
# Out:
# Country name                                                         False
# Year                                                                 False
# Reconstruction costs from drought                                     True
# Insured damages against drought                                       True
# Total economic damages from drought                                   True
#                                                                      ...
# Total economic damages from mass movements as a share of GDP          True
# Total economic damages from storms as a share of GDP                  True
# Total economic damages from volcanic activity as a share of GDP       True
# Total economic damages from volcanic activity as a share of GDP.1     True
# total_damages_pct_gdp_glacial_lake                                    True
# Length: 85, dtype: bool

# %%
natural_disaster_types = ["drought", "earthquakes", "disasters", "volcanic activity",
                          "floods", "mass movements", "storms", "landslides", "fog", 
                          "wildfires", "extreme temperatures", "glacial lake outbursts"]

# %%
# Find columns for respective disaster type

for disaster in natural_disaster_types:
    
    # Select columns related to the current disaster type
    relevant_columns = [col for col in disasters.columns if disaster in col.lower()]
    print(relevant_columns)
    print("")
# Out:
# ['Reconstruction costs from drought', 'Insured damages against drought', 'Total economic damages from drought', 'Death rates from drought', 'Injury rates from drought', 'Homelessness rate from drought', 'Total economic damages from drought as a share of GDP']
#
# ['Reconstruction costs from earthquakes', 'Insured damages against earthquakes', 'Total economic damages from earthquakes', 'Death rates from earthquakes', 'Injury rates from earthquakes', 'Homelessness rate from earthquakes', 'Total economic damages from earthquakes as a share of GDP']
#
# ['Reconstruction costs from disasters', 'Insured damages against disasters', 'Total economic damages from disasters', 'Death rates from disasters', 'Injury rates from disasters', 'Homelessness rate from disasters', 'Total economic damages from disasters as a share of GDP']
#
# ['Reconstruction costs from volcanic activity', 'Insured damages against volcanic activity', 'Total economic damages from volcanic activity', 'Death rates from volcanic activity', 'Injury rates from volcanic activity', 'Homelessness rate from volcanic activity', 'Total economic damages from volcanic activity as a share of GDP', 'Total economic damages from volcanic activity as a share of GDP.1']
#
# ['Reconstruction costs from floods', 'Insured damages against floods', 'Total economic damages from floods', 'Death rates from floods', 'Injury rates from floods', 'Homelessness rate from floods', 'Total economic damages from floods as a share of GDP']
#
# ['Reconstruction costs from mass movements', 'Insured damages against mass movements', 'Total economic damages from mass movements', 'Death rates from mass movements', 'Injury rates from mass movements', 'Homelessness rate from mass movements', 'Total economic damages from mass movements as a share of GDP']
#
# ['Reconstruction costs from storms', 'Insured damages against storms', 'Total economic damages from storms', 'Death rates from storms', 'Injury rates from storms', 'Homelessness rate from storms', 'Total economic damages from storms as a share of GDP']
#
# ['Reconstruction costs from landslides', 'Insured damages against landslides', 'Total economic damages from landslides', 'Death rates from landslides', 'Injury rates from landslides', 'Homelessness rate from landslides', 'Total economic damages from landslides as a share of GDP']
#
# ['Reconstruction costs from fog', 'Insured damages against fog', 'Total economic damages from fog', 'Death rates from fog', 'Injury rates from fog', 'Homelessness rate from fog']
#
# ['Reconstruction costs from wildfires', 'Insured damages against wildfires', 'Total economic damages from wildfires', 'Death rates from wildfires', 'Injury rates from wildfires', 'Homelessness rate from wildfires']
#
# ['Reconstruction costs from extreme temperatures', 'Insured damages against extreme temperatures', 'Total economic damages from extreme temperatures', 'Death rates from extreme temperatures', 'Injury rates from extreme temperatures', 'Homelessness rate from extreme temperatures', 'Total economic damages from extreme temperatures as a share of GDP']
#
# ['Reconstruction costs from glacial lake outbursts', 'Insured damages against glacial lake outbursts', 'Total economic damages from glacial lake outbursts', 'Death rates from glacial lake outbursts', 'Injury rates from glacial lake outbursts', 'Homelessness rate from glacial lake outbursts']

# %% [markdown]
# # 3 : World

# %%
world = pd.read_csv("data/worlddata.csv")
world.head()
# Out:
#        country  electricity_access           gdp  gdp_capita  labor_rate  \
# 0  Afghanistan               90.08  1.883323e+10      536.23       47.28
# 1      Albania               99.94  1.285605e+10     4473.89       57.54
# 2      Algeria               99.49  1.677553e+11     4117.84       41.79
# 3       Angola               43.00  7.095638e+10     2395.27       77.28
# 4    Argentina               99.90  5.801825e+11    13246.88       59.17
#
#    labor_force  land_area  life_expectancy  adult_literacy  water_access  \
# 0   9103245.75   652230.0            62.97             NaN         66.61
# 1   1362512.25    27400.0            78.93           98.14         93.92
# 2  11979207.50  2381741.0            75.79           81.41         93.73
# 3  12467594.50  1246700.0            61.39             NaN         55.46
# 4  19579367.75  2736690.0            76.73           99.10         99.01
#
#    air_pollution  population_density   population  alcohol_consumption  \
# 0         100.00               53.94  35179977.00               0.0087
# 1         100.00              104.90   2874159.25               5.0375
# 2         100.00               17.10  40736509.00               0.5844
# 3         100.00               23.82  29691157.00               7.7588
# 4          95.34               16.01  43815411.75               8.5713
#
#    unemployment_rate  social_support  freedom  generosity  \
# 0             10.341           0.522    0.428      -0.014
# 1             14.633           0.650    0.752      -0.033
# 2             10.540           0.785    0.510      -0.182
# 3              9.557             NaN      NaN         NaN
# 4              8.301           0.904    0.852      -0.187
#
#           income_class    cpi
# 0           Low income  14.25
# 1  Upper middle income  37.25
# 2  Lower middle income  34.50
# 3  Lower middle income  17.75
# 4  Upper middle income  36.75

# %%
world.shape
# Out:
# (186, 20)

# %%
world['country'].nunique()
# Out:
# 186
